# %% [markdown]
# ### **MODULE 2: Data Cleaning & Preprocessing**
#
# **Pandas Concepts:**
#
# - `.fillna()`, `.dropna()`, `.replace()`
# - `pd.to_datetime()` date conversion
# - `.str`
# - `.astype()` for type conversion
# - `.drop_duplicates()`
# - `.apply()` custom cleaning functions
#
# 1. **Date Processing:**
#     - Convert `job_posted_date` to datetime
#     - Extract: year, month, quarter, day_of_week, week_of_year
#     - Create `days_since_posted` feature

# %%
import pandas as pd
df = pd.read_csv("/Users/yerko/Desktop/Project/data/data_jobs")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785640 entries, 0 to 785639
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785640 non-null  object
#  1   job_title              785639 non-null  object
#  2   job_location           785640 non-null  object
#  3   job_via                785632 non-null  object
#  4   job_schedule_type      772975 non-null  object
#  5   job_work_from_home     785640 non-null  bool
#  6   search_location        785640 non-null  object
#  7   job_posted_date        785640 non-null  object
#  8   job_no_degree_mention  785640 non-null  float64
#  9   job_health_insurance   785640 non-null  bool
#  10  job_country            785591 non-null  object
#  11  salary_rate            33066 non-null   object
#  12  salary_year_avg        22002 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785622 non-null  object
#  15  job_skills             785640 non-null  object
#  16  job_type_skills        668654 non-null  object
#  17  Month                  785640 non-null  int64
#  18  Year                   785640 non-null  int64
#  19  Quarter                785640 non-null  int64
#  20  day_of_week            785640 non-null  int64
#  21  days_passed            785640 non-null  int64
#  22  skill_count            785640 non-null  int64
#  23  Region                 785640 non-null  object
#  24  job_posted_date_only   785640 non-null  object
#  25  health_insurance       785640 non-null  object
#  26  Degree Required        785640 non-null  bool
# dtypes: bool(3), float64(3), int64(6), object(15)
# memory usage: 146.1+ MB

# %%
# Converting job_posted_date to datetime 
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"], errors="coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785640 entries, 0 to 785639
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785640 non-null  object
#  1   job_title              785639 non-null  object
#  2   job_location           784595 non-null  object
#  3   job_via                785632 non-null  object
#  4   job_schedule_type      772975 non-null  object
#  5   job_work_from_home     785640 non-null  bool
#  6   search_location        785640 non-null  object
#  7   job_posted_date        785640 non-null  datetime64[ns]
#  8   job_no_degree_mention  785640 non-null  float64
#  9   job_health_insurance   785640 non-null  float64
#  10  job_country            785591 non-null  object
#  11  salary_rate            33066 non-null   object
#  12  salary_year_avg        22002 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785622 non-null  object
#  15  job_skills             668654 non-null  object
#  16  job_type_skills        668654 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(4), object(11)
# memory usage: 96.7+ MB

# %%
#Extracting 
df["Month"]       = df["job_posted_date"].dt.month
df["Year"]        = df["job_posted_date"].dt.year
df["Quarter"]     = df["job_posted_date"].dt.quarter
df["day_of_week"] = df["job_posted_date"].dt.day_of_week

# %%
#Days since column
from datetime import datetime
print(datetime.today())
interval = datetime.today() - df["job_posted_date"][0]
print(interval.days)
df['days_passed'] = (datetime.today() - df["job_posted_date"]).dt.days
# Out:
# 2026-01-24 12:02:56.659964
# 952

# %% [markdown]
# 2. **Text Cleaning:**
#     - Parse `job_skills` column (string representation of lists)
#     - Extract individual skills into new structure
#     - Clean company names (remove special characters)
#     - Standardize job titles

# %%
# string representation -> list
import ast
df["job_skills"] = df["job_skills"].apply(lambda s: ast.literal_eval(s) if pd.notna(s) else [])

# %%
print(type(df["job_skills"][1]))
# Out:
# <class 'list'>

# %%
extracted_skills = df.explode('job_skills')

# %%
df.head(100)
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1           Data Analyst                                       Data Analyst
# 2          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4          Data Engineer                             Data Engineer- Sr Jobs
# ..                   ...                                                ...
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                     job_location                         job_via  \
# 0                  Watertown, CT                 via Work Nearby
# 1   Guadalajara, Jalisco, Mexico                via BeBee México
# 2                Berlin, Germany                    via LinkedIn
# 3                San Antonio, TX               via Diversity.com
# 4                 Washington, DC              via Clearance Jobs
# ..                           ...                             ...
# 95    Mumbai, Maharashtra, India  via Crimsoniteam.freshteam.com
# 96                  Torrance, CA                    via LinkedIn
# 97                United Kingdom                   via Totaljobs
# 98           Toronto, ON, Canada  via SmartRecruiters Job Search
# 99                     Miami, FL                    via LinkedIn
#
#            job_schedule_type  job_work_from_home            search_location  \
# 0                  Full-time               False       Texas, United States
# 1                  Full-time               False                     Mexico
# 2                  Full-time               False                    Germany
# 3                  Full-time               False       Texas, United States
# 4                  Full-time               False                      Sudan
# ..                       ...                 ...                        ...
# 95                 Full-time               False                      India
# 96                 Full-time               False                      Sudan
# 97  Full-time and Contractor               False             United Kingdom
# 98                 Full-time               False                     Canada
# 99                 Full-time               False  California, United States
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  ...  \
# 0  2023-06-16 13:44:15                    0.0                   0.0  ...
# 1  2023-01-14 13:18:07                    0.0                   0.0  ...
# 2  2023-10-10 13:14:55                    0.0                   0.0  ...
# 3  2023-07-04 13:01:41                    1.0                   0.0  ...
# 4  2023-08-07 14:29:36                    0.0                   0.0  ...
# ..                 ...                    ...                   ...  ...
# 95 2023-07-31 13:35:48                    0.0                   0.0  ...
# 96 2023-06-15 14:03:55                    0.0                   0.0  ...
# 97 2023-12-04 13:14:01                    1.0                   0.0  ...
# 98 2023-09-01 13:42:05                    1.0                   0.0  ...
# 99 2023-09-12 13:09:28                    0.0                   0.0  ...
#
#    salary_year_avg salary_hour_avg                           company_name  \
# 0              NaN             NaN                   Boehringer Ingelheim
# 1              NaN             NaN             Hewlett Packard Enterprise
# 2              NaN             NaN               ALPHA Augmented Services
# 3              NaN             NaN           Southwest Research Institute
# 4              NaN             NaN                        Kristina Daniel
# ..             ...             ...                                    ...
# 95             NaN             NaN                Crimson Interactive Inc
# 96             NaN             NaN                        King's Hawaiian
# 97             NaN             NaN  Solihull Metropolitan Borough Council
# 98             NaN             NaN                 MUFG Investor Services
# 99             NaN             NaN                                  Agoda
#
#                                            job_skills  \
# 0                                                  []
# 1          [r, python, sql, nosql, power bi, tableau]
# 2   [python, sql, c#, azure, airflow, dax, docker,...
# 3   [python, c++, java, matlab, aws, tensorflow, k...
# 4   [bash, python, oracle, aws, ansible, puppet, j...
# ..                                                ...
# 95  [nosql, mongodb, mongodb, elasticsearch, mysql...
# 96  [sql, r, python, sql server, azure, aws, spark...
# 97                                                 []
# 98                   [python, aws, databricks, spark]
# 99  [scala, java, golang, sql, react, spark, hadoo...
#
#                                       job_type_skills Month  Year  Quarter  \
# 0                                                 NaN     6  2023        2
# 1   {'analyst_tools': ['power bi', 'tableau'], 'pr...     1  2023        1
# 2   {'analyst_tools': ['dax'], 'cloud': ['azure'],...    10  2023        4
# 3   {'cloud': ['aws'], 'libraries': ['tensorflow',...     7  2023        3
# 4   {'cloud': ['oracle', 'aws'], 'other': ['ansibl...     8  2023        3
# ..                                                ...   ...   ...      ...
# 95  {'analyst_tools': ['tableau'], 'databases': ['...     7  2023        3
# 96  {'analyst_tools': ['sap'], 'cloud': ['azure', ...     6  2023        2
# 97                                                NaN    12  2023        4
# 98  {'cloud': ['aws', 'databricks'], 'libraries': ...     9  2023        3
# 99  {'libraries': ['react', 'spark', 'hadoop'], 'o...     9  2023        3
#
#     day_of_week  days_passed
# 0             4          952
# 1             5         1105
# 2             1          836
# 3             1          934
# 4             0          900
# ..          ...          ...
# 95            0          907
# 96            3          953
# 97            0          781
# 98            4          875
# 99            1          864
#
# [100 rows x 22 columns]

# %%
job_titles = df['job_title_short'].unique() 
job_names = df["job_title"].unique()
for name in job_titles:
    print(name)
     
title_mapping = {
    'software developer': 'software engineer',
    's w engineer': 'software engineer',
    'senior software engineer': 'software engineer',
}
# Out:
# Senior Data Engineer
# Data Analyst
# Data Engineer
# Business Analyst
# Data Scientist
# Machine Learning Engineer
# Senior Data Analyst
# Cloud Engineer
# Senior Data Scientist
# Software Engineer

# %% [markdown]
# 3. **Feature Engineering:**
#     - Create `is_remote` binary feature
#     - Categorize salaries into bins (Entry/Mid/Senior/Executive)
#     - Create `skill_count` column
#     - Generate `has_degree_requirement` flag

# %%
df['is_remote'] = df['job_work_from_home'] == 1
df['has_degree_requirement'] = df['job_degree_required'] == 1

# %%
jobs_with_salary = df.dropna(subset="salary_year_avg")

def get_salary_category(salary):
    if salary >= 100000: 
        return "Senior"
    elif salary >= 50000:
        return "Mid"
    else:
        return "Junior"
    
jobs_with_salary['Salary Category'] = jobs_with_salary["salary_year_avg"].apply(get_salary_category)
jobs_with_salary
# Out:
# /var/folders/3h/b50xl5913dl0kqp7zbychznr0000gn/T/ipykernel_15793/4157950148.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs_with_salary['Salary Category'] = jobs_with_salary["salary_year_avg"].apply(get_salary_category)
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785523   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785540   Data Engineer                                      Data Engineer
# 785547  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785581  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785591  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 109                                    Anywhere       via Get.It
# ...                                         ...              ...
# 785523                          Mt Prospect, IL  via Ai-Jobs.net
# 785540                             New York, NY         via Dice
# 785547                        Pleasant Hill, CA  via Ai-Jobs.net
# 785581                      Reutlingen, Germany  via Ai-Jobs.net
# 785591                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 109            Full-time                True    Illinois, United States
# ...                  ...                 ...                        ...
# 785523         Full-time               False    Illinois, United States
# 785540         Full-time               False                    Georgia
# 785547         Full-time               False  California, United States
# 785581         Full-time               False                    Germany
# 785591         Full-time               False    Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  ...  \
# 28     2023-08-01 13:37:57                    0.0                   0.0  ...
# 77     2023-06-26 14:22:54                    0.0                   0.0  ...
# 92     2023-02-21 13:29:59                    0.0                   1.0  ...
# 100    2023-07-31 13:01:18                    0.0                   1.0  ...
# 109    2023-10-12 13:02:19                    0.0                   1.0  ...
# ...                    ...                    ...                   ...  ...
# 785523 2023-08-31 06:02:16                    0.0                   1.0  ...
# 785540 2023-01-04 16:36:07                    1.0                   0.0  ...
# 785547 2023-04-12 06:02:51                    0.0                   1.0  ...
# 785581 2023-03-04 06:16:08                    0.0                   0.0  ...
# 785591 2023-04-21 06:02:31                    0.0                   1.0  ...
#
#        salary_hour_avg                     company_name  \
# 28                 NaN                         Netskope
# 77                 NaN                       Intelletec
# 92                 NaN                     Apex Systems
# 100                NaN                           TikTok
# 109                NaN  Get It Recruit - Transportation
# ...                ...                              ...
# 785523             NaN                      Bosch Group
# 785540             NaN            Engage Partners, Inc.
# 785547             NaN                           84.51°
# 785581             NaN                      Bosch Group
# 785591             NaN                           Tenet3
#
#                                                job_skills  \
# 28                                          [gdpr, excel]
# 77      [mongodb, mongodb, python, r, sql, mysql, mari...
# 92                                          [sql, python]
# 100                             [sql, r, python, express]
# 109                         [python, r, alteryx, tableau]
# ...                                                   ...
# 785523  [go, python, r, sql, oracle, windows, alteryx,...
# 785540                                                 []
# 785547                  [python, azure, snowflake, spark]
# 785581       [python, hadoop, spark, airflow, kubernetes]
# 785591                                [python, matlab, r]
#
#                                           job_type_skills Month  Year Quarter  \
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...     8  2023       3
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...     6  2023       2
# 92                     {'programming': ['sql', 'python']}     2  2023       1
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...     7  2023       3
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...    10  2023       4
# ...                                                   ...   ...   ...     ...
# 785523  {'analyst_tools': ['alteryx', 'power bi', 'tab...     8  2023       3
# 785540                                                NaN     1  2023       1
# 785547  {'cloud': ['azure', 'snowflake'], 'libraries':...     4  2023       2
# 785581  {'libraries': ['hadoop', 'spark', 'airflow'], ...     3  2023       1
# 785591         {'programming': ['python', 'matlab', 'r']}     4  2023       2
#
#         day_of_week  days_passed  Salary Category
# 28                1          906           Senior
# 77                0          942           Senior
# 92                1         1067           Senior
# 100               0          907           Senior
# 109               3          834              Mid
# ...             ...          ...              ...
# 785523            3          877           Senior
# 785540            2         1115           Senior
# 785547            2         1018           Senior
# 785581            5         1057           Senior
# 785591            4         1009           Senior
#
# [22002 rows x 23 columns]

# %%
df['skill_count'] = df["job_skills"].apply(lambda skills: len(skills))
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785635     Software Engineer
# 785636          Data Analyst
# 785637      Business Analyst
# 785638         Data Engineer
# 785639     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785635                                    DevOps Engineer
# 785636                                   CRM Data Analyst
# 785637                     Commercial Analyst - Start Now
# 785638  Principal Associate, Data Engineer (Remote-Eli...
# 785639                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785635                            Singapura        melalui Trabajo.org
# 785636                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785637                             Malaysia           melalui Ricebowl
# 785638  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785639                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785635   Pekerjaan tetap               False             Singapore
# 785636   Pekerjaan tetap               False               Germany
# 785637   Pekerjaan tetap               False              Malaysia
# 785638   Pekerjaan tetap               False                 Sudan
# 785639   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  ...  \
# 0      2023-06-16 13:44:15                    0.0                   0.0  ...
# 1      2023-01-14 13:18:07                    0.0                   0.0  ...
# 2      2023-10-10 13:14:55                    0.0                   0.0  ...
# 3      2023-07-04 13:01:41                    1.0                   0.0  ...
# 4      2023-08-07 14:29:36                    0.0                   0.0  ...
# ...                    ...                    ...                   ...  ...
# 785635 2023-03-13 06:16:16                    0.0                   0.0  ...
# 785636 2023-03-12 06:18:18                    0.0                   0.0  ...
# 785637 2023-03-12 06:32:36                    0.0                   0.0  ...
# 785638 2023-03-12 06:32:15                    0.0                   0.0  ...
# 785639 2023-03-13 06:16:31                    0.0                   0.0  ...
#
#        salary_hour_avg                        company_name  \
# 0                  NaN                Boehringer Ingelheim
# 1                  NaN          Hewlett Packard Enterprise
# 2                  NaN            ALPHA Augmented Services
# 3                  NaN        Southwest Research Institute
# 4                  NaN                     Kristina Daniel
# ...                ...                                 ...
# 785635             NaN  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785636             NaN                    HABA FAMILYGROUP
# 785637             NaN               Lendlease Corporation
# 785638             NaN                         Capital One
# 785639             NaN                              Trigyn
#
#                                                job_skills  \
# 0                                                      []
# 1              [r, python, sql, nosql, power bi, tableau]
# 2       [python, sql, c#, azure, airflow, dax, docker,...
# 3       [python, c++, java, matlab, aws, tensorflow, k...
# 4       [bash, python, oracle, aws, ansible, puppet, j...
# ...                                                   ...
# 785635  [bash, python, perl, linux, unix, kubernetes, ...
# 785636                             [sas, sas, sql, excel]
# 785637                                [powerpoint, excel]
# 785638  [python, go, nosql, sql, mongo, shell, mysql, ...
# 785639                                        [aws, flow]
#
#                                           job_type_skills Month  Year Quarter  \
# 0                                                     NaN     6  2023       2
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...     1  2023       1
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...    10  2023       4
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...     7  2023       3
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...     8  2023       3
# ...                                                   ...   ...   ...     ...
# 785635  {'os': ['linux', 'unix'], 'other': ['kubernete...     3  2023       1
# 785636  {'analyst_tools': ['sas', 'excel'], 'programmi...     3  2023       1
# 785637         {'analyst_tools': ['powerpoint', 'excel']}     3  2023       1
# 785638  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...     3  2023       1
# 785639              {'cloud': ['aws'], 'other': ['flow']}     3  2023       1
#
#         day_of_week  days_passed  skill_count
# 0                 4          952            0
# 1                 5         1105            6
# 2                 1          836            9
# 3                 1          934            8
# 4                 0          900            9
# ...             ...          ...          ...
# 785635            0         1048            8
# 785636            6         1049            4
# 785637            6         1049            2
# 785638            6         1049           17
# 785639            0         1048            2
#
# [785640 rows x 23 columns]

# %%
df.to_csv("data_jobs", index=False)
